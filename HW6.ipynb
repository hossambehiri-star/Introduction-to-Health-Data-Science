# %%
#Multiply three by eight
print(3 * 8)

#Add thirty three to seven then divide by 5
print((33 + 7) / 5)

print(1 + 2)
print(1 + 2.)

for n in range(1, 6):
    print(n**2)


i = 1

while i**2 <= 1000:
    print(i**2)
    i += 1

print("Final i =", i)
