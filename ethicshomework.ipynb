# %% [markdown]
# # What is the primary goal of data anonymization?

# %% [markdown]
# #### What is the primary goal of data anonymization?

# %% [markdown]
# To protect the file

# %% [markdown]
# # 1.What is the primary goal of data anonymization?

# %% [markdown]
# to protect the file
